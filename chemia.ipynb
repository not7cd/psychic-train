# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams["figure.figsize"] = (8,8)

# %%
con = [0.07, 0.13, 0.2, 0.27, 0.33]
log_con = np.log(con)
time = [85., 43., 29., 23., 17.]


k, b = np.polyfit(time, log_con, 1)
print(k, b, log_con)
# Out:
# -0.022065761019284414 -0.8759919603199555 [-2.65926004 -2.04022083 -1.60943791 -1.30933332 -1.10866262]

# %%
fig = plt.figure()
ax = fig.gca()
# ax.set_yscale('log')

# plt.xlabel('odrotność temperatury [1/K]')
# plt.ylabel('log ciśnienie [ln(hPa)]')
plt.errorbar(y=log_con, x=time, yerr=0., xerr=1, fmt='.')
plt.plot(time, np.add(np.multiply(k, time), b), '--')


plt.grid()
plt.show()

# %%
sm = [10.47, 184.6, 385, 528.8, 633.5, 708.8, 764.0, 803.3, 831.9, 852.0, 868.0]
sm_t = list(range(0,21,2))
sm_diff = np.subtract(910.7, sm)

sm_k, sm_b = np.polyfit(sm_t, np.log(sm_diff), 1)
print(sm_k, sm_b)

for t, d in zip(sm_t, np.log(sm_diff)):
    print('t:{}  s:{:.3f}'.format(t, d))
# Out:
# -0.1553193129434371 6.861487751112998
# t:0  s:6.803
# t:2  s:6.588
# t:4  s:6.265
# t:6  s:5.945
# t:8  s:5.625
# t:10  s:5.308
# t:12  s:4.988
# t:14  s:4.677
# t:16  s:4.367
# t:18  s:4.072
# t:20  s:3.754

# %%
fig = plt.figure()
ax = fig.gca()
# ax.set_yscale('log')

plt.xlabel('logarytm przewodnictwa [ln(lambda_inf - lambda_n)]')
plt.ylabel('czas reakcji [min]')
plt.errorbar(y=np.log(sm_diff), x=sm_t, yerr=0., xerr=0.04, fmt='.')
plt.plot(sm_t, np.add(np.multiply(sm_k, sm_t), sm_b), '--')

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...
